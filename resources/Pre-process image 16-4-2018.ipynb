# %% [markdown]
# Lets download a sample image from google maps.

# %%
from IPython.display import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Image("Guildford.jpg", width=400)

# %%
img = plt.imread("Guildford.jpg")
img.shape
# Out:
# (402, 404, 3)

# %% [markdown]
# OK the image isn't very large, but lets divide it into four 200x200 sections
