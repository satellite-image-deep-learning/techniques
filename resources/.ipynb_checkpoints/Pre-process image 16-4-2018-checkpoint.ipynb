# %% [markdown]
# Lets download a sample image from google maps.

# %%
from IPython.display import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Image("Guildford.jpg", width=800)

# %%
img = plt.imread("Guildford.jpg")
img.shape
# Out:
# (405, 720, 3)

# %% [markdown]
# OK the image isn't very large, but lets divide it into smaller units then resize to 256 x 256 as required by our models
